# %% [markdown]
# # Primero se importan las Bibliotecas a utilizar y los Datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from jupyterthemes import jtplot
jtplot.style(theme = 'monokai', context = 'notebook', ticks = True, grid = False)

# %% [markdown]
# Importar datos

# %%
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Desarrollamos el Analisis de Datos Exploratorio

# %%
# chequeamos si existen valores nulos
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <AxesSubplot: >

# %%
# chequeamos si hay valores nulos
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Chequeamos la informacion del dataframe
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Agrupar por region para ver cualquier relacion entre region y cargos

df_region = insurance_df.groupby(by ='region').mean()
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# *Agrupamos los datos por edad ("age") y examinamos la relacion entre la edad y los costos ("charges")

# %%
df_age = insurance_df.groupby(by ='age').mean()
df_age
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# ...

# %% [markdown]
# # Desarrollamos Ingenieria de Caracteristicas ( Feature Engineering)

# %%
# Chequeamos los valores unicos en la columna ´sex´
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convertimos la variable categorica a numerica
insurance_df['sex'] = insurance_df['sex'].apply(lambda x:0 if x=='female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Chequeamos los valores unicos en la columna 'smoker'
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convertimos la variable categorica a numerica
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Chequeamos los valores unicos de la columna 'region' y los convertimos a valor numerico creando nuevas columnas

insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          1
# 4   32    1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
# Eliminamos la columna region original usando el  comando drop
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Desarrollamos la Visualizacion de los Datos

# %%
insurance_df[['age', 'sex' ,'bmi' , 'children', 'smoker', 'charges'] ].hist(bins = 30 , figsize = (12 , 12))
# Out:
# array([[<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sex'}>],
#        [<AxesSubplot: title={'center': 'bmi'}>,
#         <AxesSubplot: title={'center': 'children'}>],
#        [<AxesSubplot: title={'center': 'smoker'}>,
#         <AxesSubplot: title={'center': 'charges'}>]], dtype=object)

# %%
# plot pairplot

sns.pairplot(insurance_df)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %% [markdown]
#  Calculamos y Graficamos la Matriz de correlacion
#
#  Que caracteristica tiene la correlacion mas positiva en relacion con los cargos ('charges')

# %%
insurance_df.corr()
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex       -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi        0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children   0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker    -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges    0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#            northwest  southeast  southwest
# age        -0.000407  -0.011642   0.010016
# sex        -0.011156   0.017117  -0.004184
# bmi        -0.135996   0.270025  -0.006205
# children    0.024806  -0.023066   0.021914
# smoker     -0.036945   0.068498  -0.036945
# ...

# %%
plt.figure(figsize = (10 , 10))
sns.heatmap(insurance_df.corr(), annot = True )
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Creamos los set de datos para entrenar y probar ( Training and testing Dataset)

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns = ['charges'])

y = insurance_df['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Tomar solo los valores numericos y escalarlos
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
# escalar los datos antes de alimentar el modelo (scaling) usando skitlearn
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %% [markdown]
# Dividimos los datos en 20 % para testing y 80 % para training

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 , random_state = 10)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# # Entrenamos y evaluamos un modelo de regresion Lineal utilizando Scikitlearn

# %%
# usamos el modelo de regresion lineal
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regression_model_sklearn = LinearRegression()
regression_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regresssion_model_sklearn_accuracy = regression_model_sklearn.score(X_test, y_test)
regresssion_model_sklearn_accuracy
# Out:
# 0.6953286665599772

# %%
y_predict = regression_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6536.847
# MSE = 42730370.0
# MAE = 4555.099
# R2 = 0.6953286775600349
# Adjusted R2 = 0.6859179803418121

# %% [markdown]
# # Entrenar (train) y Evaluar un Modelo de regresion basado en una red neural artificial usando Tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-09-21 03:40:58.696635: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 50)                450
#
#  activation (Activation)     (None, 50)                0
#
#  dense_1 (Dense)             (None, 150)               7650
#
#  activation_1 (Activation)   (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  activation_2 (Activation)   (None, 150)               0
#
#  dense_3 (Dense)             (None, 50)                7550
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# ...
# Total params: 38,351
# Trainable params: 38,351
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')

epochs_hist = ANN_model.fit(X_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 1s 5ms/step - loss: 0.3137 - val_loss: 0.2349
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1719 - val_loss: 0.1769
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1436 - val_loss: 0.1901
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1325 - val_loss: 0.1733
# Epoch 5/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1236 - val_loss: 0.1903
# Epoch 6/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1301 - val_loss: 0.1746
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1176 - val_loss: 0.1837
# Epoch 8/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1144 - val_loss: 0.1820
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1133 - val_loss: 0.1888
# Epoch 10/100
# ...

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 872us/step - loss: 0.2993
# Accuracy : 0.7007490992546082

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = ANN_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 840us/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6622.164
# MSE = 43853052.0
# MAE = 3785.2837
# R2 = 0.6873238220488356
# Adjusted R2 = 0.6776658706063285

# %% [markdown]
# Utilizamos la tecnica de regularizacion Dropout para mejorar la abilidad de generalizacion de la red.
# Para Mejorar su performance

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 50)                450
#
#  activation_4 (Activation)   (None, 50)                0
#
#  dense_6 (Dense)             (None, 150)               7650
#
#  activation_5 (Activation)   (None, 150)               0
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_7 (Dense)             (None, 150)               22650
#
#  activation_6 (Activation)   (None, 150)               0
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_8 (Dense)             (None, 50)                7550
#
#  activation_7 (Activation)   (None, 50)                0
#
#  dense_9 (Dense)             (None, 1)                 51
#
# ...
# Total params: 38,351
# Trainable params: 38,351
# Non-trainable params: 0
# _________________________________________________________________
